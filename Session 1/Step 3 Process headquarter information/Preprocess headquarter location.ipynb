# %%
import pandas as pd

# %%
# read organization database

data = pd.read_excel(r'organizations.xlsx')

# %%
data.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1 Organization Name  \
# 0             0             0          feelfood
# 1             1             1         PartCycle
# 2             2             2        Kombuchery
# 3             3             3         CyberTide
# 4             4             4     nextnano GmbH
#
#                                Organization Name URL  \
# 0   https://www.crunchbase.com/organization/feelfood
# 1  https://www.crunchbase.com/organization/partcy...
# 2  https://www.crunchbase.com/organization/kombuc...
# 3  https://www.crunchbase.com/organization/cybertide
# 4  https://www.crunchbase.com/organization/nextna...
#
#                             Organization Description  \
# 0  feelfood is providing all the important nutrie...
# 1  PartCycle is a software company that specializ...
# 2  Organic and probiotic kombucha as the refreshi...
# 3  CyberTide is an AI-based Data Leak Prevention ...
# 4             Software for semiconductor nanodevices
#
#                              Organization Industries  \
# 0                    Food and Beverage, Organic Food
# 1                    Automotive, Recycling, Software
# 2  E-Commerce, Food and Beverage, Food Delivery, ...
# 3  Artificial Intelligence (AI), Compliance, Cybe...
# 4  Laser, Nanotechnology, Quantum Computing, Semi...
#
#                            Organization Location Organization Revenue Range  \
# 0  Cologne, Nordrhein-Westfalen, Germany, Europe              Less than $1M
# 1                Berlin, Berlin, Germany, Europe                        NaN
# 2                Berlin, Berlin, Germany, Europe                $1M to $10M
# 3                Berlin, Berlin, Germany, Europe                        NaN
# 4                 Poing, Bayern, Germany, Europe              Less than $1M
#
#    Total Funding Amount Total Funding Amount Currency  \
# 0                3000.0                           EUR
# 1                   NaN                           NaN
# 2                   NaN                           NaN
# 3             1520000.0                           EUR
# 4             1813158.0                           EUR
#
#    Total Funding Amount Currency (in USD) Funding Status  \
# 0                                     NaN           Seed
# 1                                     NaN           Seed
# 2                                     NaN           Seed
# 3                                     NaN           Seed
# 4                                     NaN            NaN
#
#    Number of Funding Rounds  \
# 0                         2
# 1                         1
# 2                         4
# 3                         3
# 4                        10
#
#                                       Lead Investors  \
# 0                                   Graphit NeoTaste
# 1                                                NaN
# 2                                                NaN
# 3  German Federal Ministry of Education and Research
# 4                                                NaN
#
#    Total Funding Amount (in USD) Organization Website  Unnamed: 0  \
# 0                         3480.0                  NaN         NaN
# 1                            NaN                  NaN         NaN
# 2                            NaN                  NaN         NaN
# 3                      1628554.0                  NaN         NaN
# 4                      2019107.0                  NaN         NaN
#
#   Organization Name_y  whu  WHU Company
# 0                 NaN  NaN            0
# 1                 NaN  NaN            0
# 2                 NaN  NaN            0
# 3                 NaN  NaN            0
# 4                 NaN  NaN            0

# %%
# turn the column 'Organization Location' into a list

readlist = list(data['Organization Location'])

# %%
#check the length of the list

print(len(readlist))
# Out:
# 7128

# %%
#check the first 5 observations

readlist[0:5]
# Out:
# ['Cologne, Nordrhein-Westfalen, Germany, Europe',
#  'Berlin, Berlin, Germany, Europe',
#  'Berlin, Berlin, Germany, Europe',
#  'Berlin, Berlin, Germany, Europe',
#  'Poing, Bayern, Germany, Europe']

# %%
# Lets take the first observation

locationfirst = readlist[0]

# %%
locationfirst

# this is a string with 4 elements
# Out:
# 'Cologne, Nordrhein-Westfalen, Germany, Europe'

# %%
# split this string into a list consisting of 4 elements

locationfirstsplit = locationfirst.split(',')

# %%
# show the result

locationfirstsplit

# result is a list with 4 elements; PROBLEM: element 2,3,4 start with a space
# Out:
# ['Cologne', ' Nordrhein-Westfalen', ' Germany', ' Europe']

# %%
# redefine split to make sure that elements do not start with a space

locationfirstsplitsecond = locationfirst.split(', ')
locationfirstsplitsecond
# Out:
# ['Cologne', 'Nordrhein-Westfalen', 'Germany', 'Europe']

# %%
# to select the city, we need to select the first element of the list

cityfirst = locationfirstsplitsecond[0]
cityfirst

# IMPORTANT: index of list starts with 0
# Out:
# 'Cologne'

# %%
# to select the region, we need to select the second element of the list

regionfirst = locationfirstsplitsecond[1]
regionfirst
# Out:
# 'Nordrhein-Westfalen'

# %%
# we need to do this for all observations

# create empty lists

citylist = list()
regionlist = list()

# loop over all observations

totalobservations = len(readlist)

for i in range(0, totalobservations):
    locationlist = readlist[i].split(', ')
    city = locationlist[0]
    region = locationlist[1]
    citylist.append(city)
    regionlist.append(region)

# %%
citylist[0:5]
# Out:
# ['Cologne', 'Berlin', 'Berlin', 'Berlin', 'Poing']

# %%
regionlist[0:5]
# Out:
# ['Nordrhein-Westfalen', 'Berlin', 'Berlin', 'Berlin', 'Bayern']

# %%
# transform the list into a column of the dataframe

data['City'] = pd.DataFrame(citylist)
data['Region'] = pd.DataFrame(regionlist)

# %%
# provide overview of number of observations per region

data['Region'].value_counts()
# Out:
# Region
# Berlin                    2511
# Bayern                    1356
# Nordrhein-Westfalen        884
# Baden-Wurttemberg          548
# Hamburg                    516
# Hessen                     381
# Sachsen                    240
# Niedersachsen              166
# Brandenburg                116
# Rheinland-Pfalz             98
# Sachsen-Anhalt              67
# Schleswig-Holstein          65
# Thuringen                   61
# Mecklenburg-Vorpommern      45
# Bremen                      38
# Saarland                    36
# Name: count, dtype: int64

# %%
# provide overview of number of observations per city

data['City'].value_counts()   #Munich, München and Muenchen
# Out:
# City
# Berlin       2500
# Munich        692
# Hamburg       516
# Frankfurt     191
# München       189
#              ...
# Bodnegg         1
# Mettlach        1
# Glasow          1
# Gallen          1
# Waldkirch       1
# Name: count, Length: 737, dtype: int64

# %%
# drop city column

data.drop(columns=['City'], inplace=True)

# %%
#replace character in a string

oldstring = 'München'

newstring = oldstring.replace('ü', 'ue')

newstring
# Out:
# 'Muenchen'

# %%
# replace umlaut in citylist

newcitylist = list()

for i in range(len(citylist)):
    newcity = citylist[i].replace('ü', 'ue').replace('ö', 'oe').replace('ä', 'ae').replace('Ä', 'Ae').replace('Ö', 'Oe').replace('Ü', 'Ue')
    newcitylist.append(newcity)

newcitylist[0:10]
# Out:
# ['Cologne',
#  'Berlin',
#  'Berlin',
#  'Berlin',
#  'Poing',
#  'Frankfurt',
#  'Munich',
#  'Bremen',
#  'Mainz',
#  'Munich']

# %%
# replace Munich into Muenchen

for i in range(len(newcitylist)):
    if newcitylist[i] == 'Munich':  # make sure that in the if statemen you use == and you end with :
        newcitylist[i] = 'Muenchen'

newcitylist[0:10]
# Out:
# ['Cologne',
#  'Berlin',
#  'Berlin',
#  'Berlin',
#  'Poing',
#  'Frankfurt',
#  'Muenchen',
#  'Bremen',
#  'Mainz',
#  'Muenchen']

# %%
data['City'] = pd.DataFrame(newcitylist)

# %%
data['City'].value_counts()
# Out:
# City
# Berlin             2500
# Muenchen            889
# Hamburg             516
# Frankfurt           191
# Cologne             185
#                    ...
# Frechen               1
# Wangels               1
# Soest                 1
# Friedrichshafen       1
# Bruehl                1
# Name: count, Length: 734, dtype: int64

# %%
data.shape
# Out:
# (7128, 22)

# %%
data.to_excel(r'organizations preprocessed.xlsx')
